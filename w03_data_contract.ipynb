# %% [markdown]
# <a href="https://colab.research.google.com/github/anelchik/anelsinternshipwork/blob/main/w03_data_contract.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-04 — Search Intelligence Data Contract
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. Unit of analysis + time window
#
# *One row = one what, over which dates? State it, then verify it below.*

# %%
## Unit of Analysis

One row represents one content page for one reporting day and one client from the
`fact_content_daily_performance` table.

The prediction task is to rank pages that are most likely to exhibit search-intent
mismatch using only historical observations.

## Time Window

I will develop the dataset using March 2026 (`month='2026-03'`).

This is a middle month of the panel and avoids using June 2026, which is the final
outcome month and should remain a sealed evaluation period.

# %% [markdown]
# ## 2. Fields: feature / label / context / excluded
#
# *Sort every field you plan to touch into these four buckets. Excluded needs a why.*

# %%
## Features

• Historical clicks
• Historical impressions
• Historical CTR
• Average search position
• Query diversity from fact_content_query_90d

## Label / Prediction Target

Content review priority score.

The model ranks pages that are likely to require review because their historical
search behaviour suggests possible search-intent mismatch.

## Context

• Client identifier
• Content identifier
• Report date
• Month

These fields identify observations but are not prediction targets.

## Excluded

Future clicks

Future impressions

Future CTR

Any information collected after the prediction date.

These variables leak future information and would produce unrealistically optimistic
model performance.

# %% [markdown]
# ## 3. Verify it with queries (grain, counts, missing values, windows)
#
# *Every claim above gets a query cell here. A contract claim without a query next to it is a guess.*

# %%
imma leave this empty until i inspect the schema

# %% [markdown]
# ## 4. Data limits
#
# *What can this data never tell you? Unbalanced history, GSC-only early rows, window overlaps.*

# %%
## Limitations

This project predicts pages that are likely to require content review using
historical behavioural signals.

Search intent itself is not directly observed in the warehouse.

Therefore the model predicts a proxy for search-intent mismatch rather than
ground-truth human judgement.

In addition, different clients have different historical coverage, making the
warehouse an unbalanced panel.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
