# %% [markdown]
# <a href="https://colab.research.google.com/github/anelchik/anelsinternshipwork/blob/main/w01_research_question_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %%
'freestyle'
'I chose a freestyle project because I want to explore a problem beyond the predefined lanes. My research focuses on identifying pages where user search intent may not match the current content. Instead of only predicting declining pages, I want to investigate whether mismatches between user behavior and page content can reveal opportunities for content improvement. The goal is to build a decision-support system that helps content teams prioritize pages for review.'
# Out:
# 'I chose a freestyle project because I want to explore a problem beyond the predefined lanes. My research focuses on identifying pages where user search intent may not match the current content. Instead of only predicting declining pages, I want to investigate whether mismatches between user behavior and page content can reveal opportunities for content improvement. The goal is to build a decision-support system that helps content teams prioritize pages for review.'

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %%
'Research Question

Can we identify pages where user search intent does not match the current content using observable search and engagement signals?

Decision

Decide which pages should be prioritized for manual content review because they may no longer satisfy user expectations.

Action

SEO specialists and content editors review these pages, update their content, improve relevance, or adjust metadata.

Cost of a wrong call

If we recommend the wrong pages, the team wastes time reviewing low-impact content while truly important pages continue losing visibility and engagement.'
# Out:
#   File "/tmp/ipykernel_610/1575137435.py", line 1
#     'Research Question
#     ^
# SyntaxError: unterminated string literal (detected at line 1)

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
The available data suggests that this problem is worth investigating.

• The warehouse contains 519,606 unique content pages.

• Daily performance data includes 78,835,655 observations across multiple clients.

• Search impressions are available for 28,970,051 daily records, providing a strong signal for studying user behavior.

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %%
This work can identify patterns that suggest possible mismatches between user intent and page content based on observable search and engagement signals.

The project provides decision support rather than proof.

It cannot prove that updating a page will improve rankings or traffic, nor can it determine Google's ranking algorithm or establish causal relationships.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
